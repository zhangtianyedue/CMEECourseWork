# %%
# !pip install numpy matplotlib
import numpy as np
import matplotlib.pyplot as plt

def logistic_map(N, r):
    return r * N * (1 - N)

def bifurcation_diagram(r_min=2.5, r_max=4.0, steps=1000, discard=200, resolution=4000):
    """
    Generate (r, N) pairs for a bifurcation diagram of the logistic map:
       N_{t+1} = r * N_t * (1 - N_t).

    Parameters:
      r_min, r_max : range of r values.
      steps        : total number of iterations per r.
      discard      : how many initial iterations to discard as 'transient'.
      resolution   : how many r-values to sample.

    Returns:
      (r_vals, N_vals) as arrays that can be plotted (scatter) to see the bifurcation.
    """
    r_values = np.linspace(r_min, r_max, resolution)
    r_list = []
    N_list = []

    for r in r_values:
        # start from random initial condition in (0,1)
        N = np.random.rand()
        # iterate for 'discard' steps to let transients die out
        for _ in range(discard):
            N = logistic_map(N, r)
        # now record the next 'steps-discard' values
        for _ in range(discard, steps):
            N = logistic_map(N, r)
            r_list.append(r)
            N_list.append(N)

    return np.array(r_list), np.array(N_list)

# Run the bifurcation
r_bif, N_bif = bifurcation_diagram(
    r_min=2.5, r_max=4.0, steps=1000, discard=200, resolution=2000
)

# Plot the bifurcation diagram
plt.figure(figsize=(7,5))
plt.scatter(r_bif, N_bif, s=0.1, color='black')
plt.xlabel('r')
plt.ylabel('Long-term N')
plt.title('Bifurcation Diagram: Logistic Map')
plt.show()
# Out:
# Requirement already satisfied: numpy in /Users/tianyezhang/myenv/lib/python3.13/site-packages (2.2.1)
# Requirement already satisfied: matplotlib in /Users/tianyezhang/myenv/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/tianyezhang/myenv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
